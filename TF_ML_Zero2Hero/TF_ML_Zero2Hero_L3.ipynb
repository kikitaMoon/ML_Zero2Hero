# %% [markdown]
# # ML Zero to Hero - Lesson 3 - Introducing convolutional neural network

# %% [markdown]
# ## Essential concepts
#
# CNN is something like Filter:
# ![image.png](attachment:f7b452ac-3ca9-4239-ba50-6a84b0278c5b.png)
#
# also like:
#
# vertical filter:
# ![image.png](attachment:eb581aba-1de6-40f6-9651-30fed13cd881.png)
#
# horizontal filter:
# ![image.png](attachment:98bf38ec-a8ac-4ff8-be18-87e96b5ff28d.png)
#
# MaxPooling 2*2:
# ![image.png](attachment:cb57c771-e77d-4cb2-85b5-97bafc8aa72b.png)
# ![image.png](attachment:4c1f9650-40af-4445-984b-9e3635a7bd2b.png)

# %% [markdown]
# ## Shoe Filter
#
# ![image.png](attachment:ecaf1fa6-a792-474f-ab9a-ad111a09f5ab.png)

# %% [markdown]
# ## coding

# %%
model.add(keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)))   # 64 random filters

model.add(keras.layers.MaxPooling2D(2,2))

model.add(keras.layers.Conv2D(64,(3,3),activation='relu'))

model.add(keras.layers.MaxPooling2D(2,2)) 

model.add(keras.layers.Flatten())

model.add(keras.layers.Dense(128,activation=tf.nn.relu))

model.add(keras.layers.Dense(10,activation=tf.nn.softmax))
