# %% [markdown]
# # 6 Training an AI to create poetry

# %% [markdown]
# **Dataset**:  ".../My_Github_Repos/TensorFlow_Zero2Hero/TF_NLP_Zero2Hero/Datasets/Poetry.txt"

# %%
# to load the txt file

import os

txtfile = os.path.join(os.getcwd() + '\Datasets\Poetry.txt')
print(txtfile)

fileObject = open(txtfile, "r")
datastore = fileObject.read()
    
print(datastore)
# Out:
# C:\Users\xia12237.AVWORLD\My_Github_Repos\TensorFlow_Zero2Hero\TF_NLP_Zero2Hero\Datasets\Poetry.txt
# In the town of Athy one Jeremy Lanigan
# Battered away til he hadnt a pound.
# His father died and made him a man again
# Left him a farm and ten acres of ground.
#
# He gave a grand party for friends and relations
# Who didnt forget him when come to the wall,
# And if youll but listen IIl make your eyes glisten
# Of the rows and the ructions of Laniganâ€™s Ball.
#
# Myself to be sure got free invitation,
# For all the nice girls and boys | might ask,
# And just in a minute both friends and relations
# Were dancing round merry as bees round a cask.
#
# Judy ODaly, that nice little milliner,
# She tipped me a wink for to give her a call,
# And | soon arrived with Peggy McGilligan
# Just in time for Laniganâ€™s Ball.

# %%
#  Input data

from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

# data = "In the town of Athy one Jeremy Lanigan \n Battered away ... ..."
corpus = datastore.lower().split("\n")
print(corpus)

tokenizer.fit_on_texts(corpus)       # corpus - 语料
total_words = len(tokenizer.word_index) + 1
print(total_words)
# Out:
# ['in the town of athy one jeremy lanigan', 'battered away til he hadnt a pound.', 'his father died and made him a man again', 'left him a farm and ten acres of ground.', '', 'he gave a grand party for friends and relations', 'who didnt forget him when come to the wall,', 'and if youll but listen iil make your eyes glisten', 'of the rows and the ructions of laniganâ€™s ball.', '', 'myself to be sure got free invitation,', 'for all the nice girls and boys | might ask,', 'and just in a minute both friends and relations', 'were dancing round merry as bees round a cask.', '', 'judy odaly, that nice little milliner,', 'she tipped me a wink for to give her a call,', 'and | soon arrived with peggy mcgilligan', 'just in time for laniganâ€™s ball.']
# 95

# %%
# Text to sequence

input_sequences = []     # Input empty list of input sequence

for line in corpus:
    print(line)
    token_list = tokenizer.texts_to_sequences([line])[0]    # generate token for earch line in former corpus
    print(token_list)
    
    for i in range(1, len(token_list) ) :
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)
    
    # print(input_sequences)
print('\n')
print(input_sequences)
# Out:
# in the town of athy one jeremy lanigan
# [6, 3, 17, 4, 18, 19, 20, 21]
# battered away til he hadnt a pound.
# [22, 23, 24, 9, 25, 2, 26]
# his father died and made him a man again
# [27, 28, 29, 1, 30, 7, 2, 31, 32]
# left him a farm and ten acres of ground.
# [33, 7, 2, 34, 1, 35, 36, 4, 37]
#
# []
# he gave a grand party for friends and relations
# [9, 38, 2, 39, 40, 5, 10, 1, 11]
# who didnt forget him when come to the wall,
# [41, 42, 43, 7, 44, 45, 8, 3, 46]
# and if youll but listen iil make your eyes glisten
# [1, 47, 48, 49, 50, 51, 52, 53, 54, 55]
# of the rows and the ructions of laniganâ€™s ball.
# [4, 3, 56, 1, 3, 57, 4, 12, 13]
#
# []
# myself to be sure got free invitation,
# [58, 8, 59, 60, 61, 62, 63]
# for all the nice girls and boys | might ask,
# [5, 64, 3, 14, 65, 1, 66, 67, 68]
, 2, 69, 70, 10, 1, 11], [71, 72], [71, 72, 16], [71, 72, 16, 73], [71, 72, 16, 73, 74], [71, 72, 16, 73, 74, 75], [71, 72, 16, 73, 74, 75, 16], [71, 72, 16, 73, 74, 75, 16, 2], [71, 72, 16, 73, 74, 75, 16, 2, 76], [77, 78], [77, 78, 79], [77, 78, 79, 14], [77, 78, 79, 14, 80], [77, 78, 79, 14, 80, 81], [82, 83], [82, 83, 84], [82, 83, 84, 2], [82, 83, 84, 2, 85], [82, 83, 84, 2, 85, 5], [82, 83, 84, 2, 85, 5, 8], [82, 83, 84, 2, 85, 5, 8, 86], [82, 83, 84, 2, 85, 5, 8, 86, 87], [82, 83, 84, 2, 85, 5, 8, 86, 87, 2], [82, 83, 84, 2, 85, 5, 8, 86, 87, 2, 88], [1, 89], [1, 89, 90], [1, 89, 90, 91], [1, 89, 90, 91, 92], [1, 89, 90, 91, 92, 93], [15, 6], [15, 6, 94], [15, 6, 94, 5], [15, 6, 94, 5, 12], [15, 6, 94, 5, 12, 13]]

# %%
# Get the max len after spliting the list into multiple text
max_sequence_len = max([len(x) for x in input_sequences])
print(max_sequence_len)
# Out:
# 11

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_sequences = pad_sequences(
                            sequences=input_sequences,  # list
                            maxlen=max_sequence_len,    # integer
                            padding='pre'
                            )
print(padded_sequences)

input_sequences = np.array(padded_sequences)
# Out:
# [[ 0  0  0 ...  0  6  3]
#  [ 0  0  0 ...  6  3 17]
#  [ 0  0  0 ...  3 17  4]
#  ...
#  [ 0  0  0 ...  6 94  5]
#  [ 0  0  0 ... 94  5 12]
#  [ 0  0  0 ...  5 12 13]]

# %% [markdown]
# ### Padded Input sequences to split to Input(X) and Label(Y)
#
# ![image.png](attachment:03a63693-79bb-4760-90fa-e266306c34db.png)

# %%
xs = input_sequences[:,:-1]
labels = input_sequences[:,-1]

# %%
# categorical function
# Converts a class vector (integers) to binary class matrix.
# link: https://keras.io/api/utils/python_utils/#to_categorical-function

import tensorflow as tf

ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)

# %% [markdown]
# ### Example:
#
# ![image.png](attachment:47466d10-3ea2-4131-8709-f6e52026d299.png)

# %%
# Create model

from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential() 

model.add(layers.Embedding(total_words, 240, input_length=max_sequence_len-1))   # Dimension=240, total words=num of unique words
model.add(layers.Bidirectional(layers.LSTM(150)))
model.add(layers.Dense(total_words, activation='softmax')) 

adam = keras.optimizers.Adam(lr=0.01)  
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

history = model.fit(xs, ys, epochs=100, verbose=1)
# Out:
# C:\Users\xia12237.AVWORLD\Anaconda3\envs\tensorflow\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/100
# 4/4 [==============================] - 3s 10ms/step - loss: 4.6109 - accuracy: 0.0256
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.3739 - accuracy: 0.1026
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 3.8096 - accuracy: 0.1197
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 3.0734 - accuracy: 0.2137
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.3103 - accuracy: 0.3504
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.6255 - accuracy: 0.4786
# Epoch 7/100
# 4/4 [==============================] - 0s 21ms/step - loss: 1.2329 - accuracy: 0.6325
# Epoch 8/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.8636 - accuracy: 0.7521
# Epoch 9/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7125 - accuracy: 0.7350
# Epoch 10/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3996 - accuracy: 0.8974
# Epoch 11/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2899 - accuracy: 0.9402
# Epoch 12/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1462 - accuracy: 0.9829
# Epoch 13/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1472 - accuracy: 0.9744
# Epoch 14/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0922 - accuracy: 0.9829
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0844 - accuracy: 0.9829
# Epoch 16/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0876 - accuracy: 0.9744
# Epoch 17/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0710 - accuracy: 0.9829
# Epoch 18/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0506 - accuracy: 0.9829
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0462 - accuracy: 0.9829
# Epoch 20/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0424 - accuracy: 0.9829
# Epoch 21/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0420 - accuracy: 0.9829
# Epoch 22/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0369 - accuracy: 0.9829
# Epoch 23/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0405 - accuracy: 0.9829
# Epoch 24/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0411 - accuracy: 0.9829
# Epoch 25/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0327 - accuracy: 0.9829
# Epoch 26/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0427 - accuracy: 0.9829
# Epoch 27/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0358 - accuracy: 0.9829
# Epoch 28/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0364 - accuracy: 0.9744
# Epoch 29/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0403 - accuracy: 0.9829
# Epoch 30/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0349 - accuracy: 0.9829
# Epoch 31/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0367 - accuracy: 0.9744
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0391 - accuracy: 0.9829
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0347 - accuracy: 0.9744
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0337 - accuracy: 0.9744
# Epoch 35/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0316 - accuracy: 0.9829
# Epoch 36/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0353 - accuracy: 0.9829
# Epoch 37/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0360 - accuracy: 0.9744
# Epoch 38/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0330 - accuracy: 0.9744
# Epoch 39/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0342 - accuracy: 0.9744
# Epoch 40/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0343 - accuracy: 0.9829
# Epoch 41/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0303 - accuracy: 0.9829
# Epoch 42/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0386 - accuracy: 0.9829
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0369 - accuracy: 0.9829
# Epoch 44/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0302 - accuracy: 0.9829
# Epoch 45/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0319 - accuracy: 0.9829
# Epoch 46/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0379 - accuracy: 0.9829
# Epoch 47/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0340 - accuracy: 0.9829
# Epoch 48/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0371 - accuracy: 0.9744
# Epoch 49/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0333 - accuracy: 0.9829
# Epoch 50/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0349 - accuracy: 0.9829
# Epoch 51/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0331 - accuracy: 0.9829
# Epoch 52/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0316 - accuracy: 0.9829
# Epoch 53/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0328 - accuracy: 0.9744
# Epoch 54/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0344 - accuracy: 0.9829
# Epoch 55/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0333 - accuracy: 0.9744
# Epoch 56/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0348 - accuracy: 0.9744
# Epoch 57/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0370 - accuracy: 0.9829
# Epoch 58/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0317 - accuracy: 0.9829
# Epoch 59/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0301 - accuracy: 0.9829
# Epoch 60/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0364 - accuracy: 0.9744
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0333 - accuracy: 0.9829
# Epoch 62/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0335 - accuracy: 0.9744
# Epoch 63/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0304 - accuracy: 0.9829
# Epoch 64/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0311 - accuracy: 0.9829
# Epoch 65/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0312 - accuracy: 0.9829
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 0.9829
# Epoch 67/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0306 - accuracy: 0.9829
# Epoch 68/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0304 - accuracy: 0.9829
# Epoch 69/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0313 - accuracy: 0.9829
# Epoch 70/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0327 - accuracy: 0.9829
# Epoch 71/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0335 - accuracy: 0.9829
# Epoch 72/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0316 - accuracy: 0.9829
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0302 - accuracy: 0.9829
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0309 - accuracy: 0.9829
# Epoch 75/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0332 - accuracy: 0.9829
# Epoch 76/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0298 - accuracy: 0.9829
# Epoch 77/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0314 - accuracy: 0.9829
# Epoch 78/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0344 - accuracy: 0.9744
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0326 - accuracy: 0.9744
# Epoch 80/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0299 - accuracy: 0.9829
# Epoch 81/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0334 - accuracy: 0.9744
# Epoch 82/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0308 - accuracy: 0.9744
# Epoch 83/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0293 - accuracy: 0.9829
# Epoch 84/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0343 - accuracy: 0.9829
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0313 - accuracy: 0.9829
# Epoch 86/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0346 - accuracy: 0.9744
# Epoch 87/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0319 - accuracy: 0.9744
# Epoch 88/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0308 - accuracy: 0.9829
# Epoch 89/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0297 - accuracy: 0.9829
# Epoch 90/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0320 - accuracy: 0.9744
# Epoch 91/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0314 - accuracy: 0.9744
# Epoch 92/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0310 - accuracy: 0.9829
# Epoch 93/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0306 - accuracy: 0.9744
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0317 - accuracy: 0.9829
# Epoch 95/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0319 - accuracy: 0.9829
# Epoch 96/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0317 - accuracy: 0.9829
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0313 - accuracy: 0.9829
# Epoch 98/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0316 - accuracy: 0.9744
# Epoch 99/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0304 - accuracy: 0.9829
# Epoch 100/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0335 - accuracy: 0.9829

# %%
# Predict the word 

seed_text = "I made a poetry machine"
next_words = 20

for index in range(next_words) :
    
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    print(token_list)                         
                               
    # predicted = model.predict_classes(token_list, verbose=0)
    # the above line from the TensorFlow lesson does not work
    # the function in use is no longer supported in TensorFlow 2.6
    
    predicted = model.predict(token_list, verbose=0)
    classes_predict = np.argmax(predicted,axis=1)
    
    output_word = ""
    for word, index in tokenizer.word_index.items():
        # print(word,index)
        if index == classes_predict:
            output_word = word
            break

    seed_text += "   " + output_word

print(seed_text)
# Out:
# [[ 0  0  0  0  0  0  0  0 30  2]]
# [[ 0  0  0  0  0  0  0 30  2 23]]
# [[ 0  0  0  0  0  0 30  2 23 24]]
# [[ 0  0  0  0  0 30  2 23 24  9]]
# [[ 0  0  0  0 30  2 23 24  9 25]]
# [[ 0  0  0 30  2 23 24  9 25  2]]
# [[ 0  0 30  2 23 24  9 25  2 26]]
# [[ 0 30  2 23 24  9 25  2 26 26]]
# [[30  2 23 24  9 25  2 26 26 32]]
# [[ 2 23 24  9 25  2 26 26 32 88]]
# [[23 24  9 25  2 26 26 32 88 88]]
# [[24  9 25  2 26 26 32 88 88 11]]
# [[ 9 25  2 26 26 32 88 88 11 11]]
# [[25  2 26 26 32 88 88 11 11 11]]
# [[ 2 26 26 32 88 88 11 11 11 11]]
# [[26 26 32 88 88 11 11 11 11 15]]
# [[26 32 88 88 11 11 11 11 15  2]]
# [[32 88 88 11 11 11 11 15  2 69]]
# [[88 88 11 11 11 11 15  2 69 70]]
# [[88 11 11 11 11 15  2 69 70 10]]
# I made a poetry machine   away   til   he   hadnt   a   pound   pound   again   call   call   relations   relations   relations   relations   just   a   minute   both   friends   and
